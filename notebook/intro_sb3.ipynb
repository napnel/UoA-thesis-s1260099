# %%
import gym
from stable_baselines3 import DQN, PPO
import torch as th

# %%
env = gym.make("CartPole-v0")

import os
if not os.path.exists('dqn_cartpole.zip'):
    model = PPO("MlpPolicy", env, verbose=1, device='cpu', tensorboard_log='../logs')
    model.learn(total_timesteps=100000)
    model.save("dqn_cartpole")
    del model
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Logging to ../logs\PPO_11
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 42.3        |
# |    ep_rew_mean          | 42.3        |
# | time/                   |             |
# |    fps                  | 1360        |
# |    iterations           | 4           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009837633 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.265       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.2        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0213     |
# |    value_loss           | 49          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.4        |
# |    ep_rew_mean          | 96.4        |
# | time/                   |             |
# |    fps                  | 1308        |
# |    iterations           | 8           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007564872 |
# |    clip_fraction        | 0.0767      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.559      |
# |    explained_variance   | 0.646       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13          |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 54.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 153          |
# |    ep_rew_mean          | 153          |
# | time/                   |              |
# |    fps                  | 1293         |
# |    iterations           | 12           |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0033956603 |
# |    clip_fraction        | 0.0255       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.532       |
# |    explained_variance   | 0.447        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 51           |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.0022      |
# |    value_loss           | 106          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 193          |
# |    ep_rew_mean          | 193          |
# | time/                   |              |
# |    fps                  | 1297         |
# |    iterations           | 16           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0015728432 |
# |    clip_fraction        | 0.00273      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.505       |
# |    explained_variance   | 0.335        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 53.2         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.000888    |
# |    value_loss           | 134          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 200           |
# |    ep_rew_mean          | 200           |
# | time/                   |               |
# |    fps                  | 1299          |
# |    iterations           | 20            |
# |    time_elapsed         | 31            |
# |    total_timesteps      | 40960         |
# | train/                  |               |
# |    approx_kl            | 0.00092300854 |
# |    clip_fraction        | 0.00103       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.5          |
# |    explained_variance   | 0.0376        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 52.8          |
# |    n_updates            | 190           |
# |    policy_gradient_loss | 1.26e-05      |
# |    value_loss           | 186           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | 199         |
# | time/                   |             |
# |    fps                  | 1294        |
# |    iterations           | 24          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.005090845 |
# |    clip_fraction        | 0.028       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.475      |
# |    explained_variance   | 0.264       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 107         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00304    |
# |    value_loss           | 167         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 199         |
# |    ep_rew_mean          | 199         |
# | time/                   |             |
# |    fps                  | 1289        |
# |    iterations           | 28          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.006162795 |
# |    clip_fraction        | 0.0284      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.459      |
# |    explained_variance   | 0.177       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 79.7        |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00138    |
# |    value_loss           | 165         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1289         |
# |    iterations           | 32           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0029410578 |
# |    clip_fraction        | 0.0198       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.404       |
# |    explained_variance   | 0.178        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 62.2         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.0024      |
# |    value_loss           | 173          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1288         |
# |    iterations           | 36           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0036812369 |
# |    clip_fraction        | 0.028        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.381       |
# |    explained_variance   | 0.364        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 25.8         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 161          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1285         |
# |    iterations           | 40           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0010007801 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.379       |
# |    explained_variance   | 0.787        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 28.9         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.000919    |
# |    value_loss           | 81.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1284         |
# |    iterations           | 44           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0019033728 |
# |    clip_fraction        | 0.00405      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.346       |
# |    explained_variance   | 0.573        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 72.4         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.000459    |
# |    value_loss           | 142          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 200          |
# |    ep_rew_mean          | 200          |
# | time/                   |              |
# |    fps                  | 1285         |
# |    iterations           | 48           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0020958623 |
# |    clip_fraction        | 0.00903      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.334       |
# |    explained_variance   | 0.767        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 18.9         |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.000707    |
# |    value_loss           | 83.5         |
# ------------------------------------------

# %%
def evaluate(model, env, render=True):
    obs = env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        if render:
            env.render()

    env.close()

# %%
model = PPO.load("dqn_cartpole", device='cpu')
evaluate(model, env)

# %%
from stable_baselines3.common.utils import obs_as_tensor
def get_action_prob(obaservation):
    obs = obaservation.reshape((-1,) + env.observation_space.shape)
    obs = obs_as_tensor(obs, model.device)
    latent_pi, _, latent_sde = model.policy._get_latent(obs)
    distribution = model.policy._get_action_dist_from_latent(latent_pi, latent_sde)
    action_prob = distribution.distribution.probs
    return action_prob.detach().numpy()

# %%
obs = env.reset()

for i in range(50):
    action, _states = model.predict(obs, deterministic=True)
    print(get_action_prob(obs), action)
    obs, reward, done, info = env.step(action)
    if done:
        break
# Out:
# [[0.81320137 0.18679859]] 0
# [[0.03986129 0.9601387 ]] 1
# [[0.87811095 0.121889  ]] 0
# [[0.06040519 0.93959486]] 1
# [[0.9190455  0.08095451]] 0
# [[0.09024318 0.9097568 ]] 1
# [[0.9451997  0.05480025]] 0
# [[0.13307494 0.86692506]] 1
# [[0.9623296 0.0376704]] 0
# [[0.19357651 0.8064235 ]] 1
# [[0.9738495  0.02615046]] 0
# [[0.2766591  0.72334087]] 1
# [[0.98177516 0.01822487]] 0
# [[0.38511208 0.61488795]] 1
# [[0.98731774 0.01268221]] 0
# [[0.5152731  0.48472694]] 0
# [[0.0143902 0.9856098]] 1
# [[0.59154177 0.40845814]] 0
# [[0.01713817 0.9828619 ]] 1
# [[0.6413422  0.35865778]] 0
# [[0.01920558 0.9807944 ]] 1
# [[0.6683792 0.3316208]] 0
# [[0.02024192 0.979758  ]] 1
# [[0.6757409  0.32425916]] 0
# [[0.02006352 0.9799365 ]] 1
# [[0.6645577  0.33544236]] 0
# [[0.01870253 0.9812975 ]] 1
# [[0.63381684 0.3661832 ]] 0
# [[0.01639649 0.9836035 ]] 1
# [[0.5808036  0.41919646]] 0
# [[0.01352314 0.9864769 ]] 1
# [[0.502667 0.497333]] 0
# [[0.01050215 0.9894979 ]] 1
# [[0.4002229  0.59977716]] 1
# [[0.98289466 0.01710535]] 0
# [[0.33993742 0.6600626 ]] 1
# [[0.97968894 0.02031108]] 0
# [[0.2917029 0.7082971]] 1
# [[0.97632444 0.02367551]] 0
# [[0.2532407  0.74675924]] 1
# [[0.9728352  0.02716485]] 0
# [[0.22236797 0.77763206]] 1
# [[0.9692369  0.03076312]] 0
# [[0.19724989 0.8027501 ]] 1
# [[0.96552384 0.03447617]] 0
# [[0.1764332  0.82356685]] 1
# [[0.9616656  0.03833439]] 0
# [[0.15879788 0.84120214]] 1
# [[0.95760417 0.04239575]] 0
# [[0.14349066 0.8565093 ]] 1
